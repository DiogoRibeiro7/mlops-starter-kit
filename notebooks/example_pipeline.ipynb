# %% [markdown]
# # Example Pipeline
# This notebook demonstrates loading data, training, and evaluation.

# %%
from mlops_starter_kit.utils import load_data, split_data, train_model, evaluate_model
from pathlib import Path
df = load_data(Path('data/raw/example.csv'))
X_train, X_test, y_train, y_test = split_data(df, 'target')
model = train_model(X_train, y_train)
metrics = evaluate_model(model, X_test, y_test)
metrics
